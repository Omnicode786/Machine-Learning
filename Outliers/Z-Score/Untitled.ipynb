# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('placement.csv')

# %%
df.head()
# Out:
#    cgpa  placement_exam_marks  placed
# 0  7.19                  26.0       1
# 1  7.46                  38.0       1
# 2  7.54                  40.0       1
# 3  6.42                   8.0       1
# 4  7.23                  17.0       0

# %%
sns.distplot(df['cgpa'])
# Out:
# C:\Users\NB\AppData\Local\Temp\ipykernel_19312\2535591610.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['cgpa'])
# <Axes: xlabel='cgpa', ylabel='Density'>

# %%
plt.figure(figsize= (16, 5))
plt.subplot(1,2,1)
sns.distplot(df['cgpa'])

plt.subplot(1,2,2)
sns.distplot(df['placement_exam_marks'])
plt.show()
# Out:
# C:\Users\NB\AppData\Local\Temp\ipykernel_19312\3814475208.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['cgpa'])
# C:\Users\NB\AppData\Local\Temp\ipykernel_19312\3814475208.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['placement_exam_marks'])

# %%
# as we can see that districution of cgpa is very well normally distributed
# so we can apply Z score only on cgpafeature

# %%
print(df['cgpa'].mean())
print(df['cgpa'].max())
print(df['cgpa'].min())
# Out:
# 6.96124
# 9.12
# 4.89

# %%
print(df['cgpa'].std())
# Out:
# 0.6158978751323894

# %%
print(df['cgpa'].mean() -3* df['cgpa'].std())
# Out:
# 5.113546374602832

# %%
print(df['cgpa'].mean() +3* df['cgpa'].std())
# Out:
# 8.808933625397168

# %%
df[(df['cgpa'] > 8.8089) |( df['cgpa'] < 5.11)]
# Out:
#      cgpa  placement_exam_marks  placed
# 485  4.92                  44.0       1
# 995  8.87                  44.0       1
# 996  9.12                  65.0       1
# 997  4.89                  34.0       0
# 999  4.90                  10.0       1

# %%
# the above shows all the outliers basically

# %% [markdown]
# ## Trimming

# %%
new_df = df[(df['cgpa'] < 8.80) & (df['cgpa'] > 5.11)]

# %%
new_df.sample(4)
# Out:
#      cgpa  placement_exam_marks  placed
# 80   6.87                  46.0       1
# 581  6.57                  25.0       0
# 208  7.25                  12.0       1
# 821  6.10                   9.0       0

# %%
df.shape
# Out:
# (1000, 3)

# %%
new_df.shape
# Out:
# (995, 3)

# %%
# appraoch 2

# %% [markdown]
# ## Appraoch 2 Z score

# %%
# xi = x - u / std daviation

# %%
df['cgpa_zsore'] = (df['cgpa'] - df['cgpa'].mean()) / df['cgpa'].std()

# %%
df.head(3)
# Out:
#    cgpa  placement_exam_marks  placed  cgpa_zsore
# 0  7.19                  26.0       1    0.371425
# 1  7.46                  38.0       1    0.809810
# 2  7.54                  40.0       1    0.939701

# %%
# now find the range if th e z score came out to be highi will be terminated

# %%
# and similarly ifi it is lower it will be removed as well

# %%
new_df['cgpa_zsore'] = (df['cgpa_zscore'] - df['cgpa'].mean()) / df['cgpa'].std()
