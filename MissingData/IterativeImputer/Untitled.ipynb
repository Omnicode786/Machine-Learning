# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv('train.csv')

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
df = pd.read_csv('train.csv')[['Age','Fare','Pclass','Survived']]

# %%
df.head(4)
# Out:
#     Age     Fare  Pclass  Survived
# 0  22.0   7.2500       3         0
# 1  38.0  71.2833       1         1
# 2  26.0   7.9250       3         1
# 3  35.0  53.1000       1         1

# %%
set = df.sample(50)

# %%
set.head()
# Out:
#       Age     Fare  Pclass  Survived
# 123  32.5  13.0000       2         1
# 840  20.0   7.9250       3         0
# 228  18.0  13.0000       2         0
# 420   NaN   7.8958       3         0
# 158   NaN   8.6625       3         0

# %%
set.isnull().sum()
# Out:
# Age         13
# Fare         0
# Pclass       0
# Survived     0
# dtype: int64

# %%
new_set = set

# %%
new_set = new_set.fillna(new_set.mean())

# %%
new_set.head()
# Out:
#            Age     Fare  Pclass  Survived
# 123  32.500000  13.0000       2         1
# 840  20.000000   7.9250       3         0
# 228  18.000000  13.0000       2         0
# 420  30.671081   7.8958       3         0
# 158  30.671081   8.6625       3         0

# %%
new_set.isnull().sum()
# Out:
# Age         0
# Fare        0
# Pclass      0
# Survived    0
# dtype: int64

# %%
lr = LinearRegression()
lr
# Out:
# LinearRegression()

# %%
from sklearn.model_selection import train_test_split

# %%
set.isnull().sum()
# Out:
# Age         13
# Fare         0
# Pclass       0
# Survived     0
# dtype: int64

# %%
missing_mask = set['Age'].isna()

# %%
features = ['Fare', 'Pclass', 'Survived']

x_train = set.loc[~missing_mask, features]

# %%
x_train.head()
# Out:
#        Fare  Pclass  Survived
# 123  13.000       2         1
# 840   7.925       3         0
# 228  13.000       2         0
# 200   9.500       3         0
# 494   8.050       3         0

# %%
y_train = set.loc[~missing_mask, ['Age']]

# %%
y_train.head(3)
# Out:
#       Age
# 123  32.5
# 840  20.0
# 228  18.0

# %%
lr
# Out:
# LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
X_pred = new_set.loc[missing_mask, features]

# %%
y_pred = lr.predict(X_pred)

# %%
y_pred = pd.DataFrame(y_pred)

# %%
y_pred
# Out:
# array([[21.60431614],
#        [21.63466525],
#        [21.59854478],
#        [44.19876557],
#        [44.85190294],
#        [22.53638818],
#        [21.89525915],
#        [21.60431614],
#        [22.55700357],
#        [43.89344415],
#        [21.59854478],
#        [43.84448803],
#        [43.22051474]])

# %%
from sklearn.metrics import accuracy_score

# %%
new_set.head()
# Out:
#            Age     Fare  Pclass  Survived
# 123  32.500000  13.0000       2         1
# 840  20.000000   7.9250       3         0
# 228  18.000000  13.0000       2         0
# 420  30.671081   7.8958       3         0
# 158  30.671081   8.6625       3         0

# %%
set.head()
# Out:
#        Age     Fare  Pclass  Survived
# 123  32.50  13.0000       2         1
# 840  20.00   7.9250       3         0
# 228  18.00  13.0000       2         0
# 420    NaN   7.8958       3         0
# 158    NaN   8.6625       3         0
# 593    NaN   7.7500       3         0
# 200  28.00   9.5000       3         0
# 494  21.00   8.0500       3         0
# 244  30.00   7.2250       3         0
# 204  18.00   8.0500       3         1
# 55     NaN  35.5000       1         1
# 136  19.00  26.2833       1         1
# 417  18.00  13.0000       2         1
# 292  36.00  12.8750       2         0
# 182   9.00  31.3875       3         0
# 669    NaN  52.0000       1         1
# 473  23.00  13.7917       2         1
# 769  32.00   8.3625       3         0
# 637  31.00  26.2500       2         0
# 36     NaN   7.2292       3         1
# 140    NaN  15.2458       3         0
# 197  42.00   8.4042       3         0
# 796  49.00  25.9292       1         1
# 349  42.00   8.6625       3         0
# ...

# %%
y_pred
# Out:
#             0
# 0   21.604316
# 1   21.634665
# 2   21.598545
# 3   44.198766
# 4   44.851903
# 5   22.536388
# 6   21.895259
# 7   21.604316
# 8   22.557004
# 9   43.893444
# 10  21.598545
# 11  43.844488
# 12  43.220515

# %%
set.loc[missing_mask,'Age'] = y_pred

# %%
set.head()
# Out:
#            Age     Fare  Pclass  Survived
# 123  32.500000  13.0000       2         1
# 840  20.000000   7.9250       3         0
# 228  18.000000  13.0000       2         0
# 420  21.604316   7.8958       3         0
# 158  21.634665   8.6625       3         0
