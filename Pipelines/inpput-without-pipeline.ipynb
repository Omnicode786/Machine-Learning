# %%
import pickle
import numpy as np

# %%
hot_sex = pickle.load(open('models/hot_sex.pkl','rb'))
hot_embarked = pickle.load(open('models/hot_embarked.pkl','rb'))
clf = pickle.load(open('models/clf.pkl','rb'))

# %%
# assume the user has given some input
# Pclass ender ge sibsp parch fare embarked

test_ip = np.array([2,'male',31.0,0,0,10.5,'S'],dtype=object).reshape(1,7)

# %%
test_ip
# Out:
# array([[2, 'female', 31.0, 0, 0, 10.5, 'S']], dtype=object)

# %%
test_ip_sex = hot_sex.transform(test_ip[:,1].reshape(1,1))
# Out:
# C:\Users\NB\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but OneHotEncoder was fitted with feature names
#   warnings.warn(

# %%
test_ip_embarked = hot_embarked.transform(test_ip[:,-1].reshape(1,1))

# %%
#  toooooooooo many steps use pupielens

# %%
test_ip_age = test_ip[:,2].reshape(1,1)

# %%
test_ip_transformed = np.concatenate((test_ip[:,[0,3,4,5]],test_ip_age,test_ip_sex,test_ip_embarked),axis=1)

# %%
test_ip_transformed.shape
# Out:
# (1, 10)

# %%
print(clf.predict(test_ip_transformed))
# Out:
# [1]
