# %%
import numpy as np

# %%
np
# Out:
# <module 'numpy' from 'C:\\Users\\NB\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site-packages\\numpy\\__init__.py'>

# %%
a = np.array(4)

# %%
a
# Out:
# array(4)

# %%
a.ndim
# Out:
# 0

# %%
a = np.array([1,3,5,6])

# %%
a
# Out:
# array([1, 3, 5, 6])

# %%
a.ndim
# Out:
# 1

# %%
print("But the number of dimensions of the vector will be 4 but its a 1D tensor")
# Out:
# But the number of dimensions of the vector will be 4 but its a 1D tensor

# %%
a = np.array([[1,2,3],[4,5,6]])

# %%
a.ndim
# Out:
# 2

# %%
a.shape
# Out:
# (2, 3)
