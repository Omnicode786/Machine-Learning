# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('placement.csv')

# %%
df
# Out:
#     Unnamed: 0  cgpa     iq  placement
# 0            0   6.8  123.0          1
# 1            1   5.9  106.0          0
# 2            2   5.3  121.0          0
# 3            3   7.4  132.0          1
# 4            4   5.8  142.0          0
# ..         ...   ...    ...        ...
# 95          95   4.3  200.0          0
# 96          96   4.4   42.0          0
# 97          97   6.7  182.0          1
# 98          98   6.3  103.0          1
# 99          99   6.2  113.0          1
#
# [100 rows x 4 columns]

# %%
df.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %% [markdown]
# one column here in unnecessary so we need to do preprocessing and remove it

# %%
df.shape
# Out:
# (100, 4)

# %% [markdown]
# this means 100 rows and 4 columns

# %% [markdown]
# ![image.png](attachment:9e5d495b-ddc7-4268-81dc-1dfe4b0e0bb4.png)

# %% [markdown]
# Train test split is simply we split the data set into two jalfs one will be trainign set and the other to be testing suppose 100 students we set 90 as training now the rest 10 will be for testing if the output gives correct as the ones which we got then we have our model trained perfectly

# %%
df = df.iloc[:,1:]

# %%
df.head()
# Out:
#    cgpa     iq  placement
# 0   6.8  123.0          1
# 1   5.9  106.0          0
# 2   5.3  121.0          0
# 3   7.4  132.0          1
# 4   5.8  142.0          0

# %% [markdown]
# now we have our data pre processed and that extra unnecessary column is removed for now its manual

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['cgpa'],df['iq'], c=df['placement'])

# %%
# we will be doing logistic regression

# %%
  x = df.iloc[:,0:2]
  y = df.iloc[:,-1]

# %%
x.head()
# Out:
#    cgpa     iq
# 0   6.8  123.0
# 1   5.9  106.0
# 2   5.3  121.0
# 3   7.4  132.0
# 4   5.8  142.0

# %%
y.head()
# Out:
# 0    1
# 1    0
# 2    0
# 3    1
# 4    0
# Name: placement, dtype: int64

# %%
x
# Out:
#     cgpa     iq
# 0    6.8  123.0
# 1    5.9  106.0
# 2    5.3  121.0
# 3    7.4  132.0
# 4    5.8  142.0
# ..   ...    ...
# 95   4.3  200.0
# 96   4.4   42.0
# 97   6.7  182.0
# 98   6.3  103.0
# 99   6.2  113.0
#
# [100 rows x 2 columns]

# %%
# !pip install scikit-learn
# Out:
# Collecting scikit-learn
#   Downloading scikit_learn-1.8.0-cp312-cp312-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.24.1 in c:\users\nb\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (2.2.6)
# Requirement already satisfied: scipy>=1.10.0 in c:\users\nb\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (1.16.0)
# Collecting joblib>=1.3.0 (from scikit-learn)
#   Downloading joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# Collecting threadpoolctl>=3.2.0 (from scikit-learn)
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Downloading scikit_learn-1.8.0-cp312-cp312-win_amd64.whl (8.0 MB)
#    ---------------------------------------- 0.0/8.0 MB ? eta -:--:--
#    ----- ---------------------------------- 1.0/8.0 MB 8.4 MB/s eta 0:00:01
#    ------- -------------------------------- 1.6/8.0 MB 4.4 MB/s eta 0:00:02
#    --------- ------------------------------ 1.8/8.0 MB 3.4 MB/s eta 0:00:02
#    ---------- ----------------------------- 2.1/8.0 MB 2.6 MB/s eta 0:00:03
#    ----------- ---------------------------- 2.4/8.0 MB 2.2 MB/s eta 0:00:03
#    ------------- -------------------------- 2.6/8.0 MB 2.1 MB/s eta 0:00:03
#    -------------- ------------------------- 2.9/8.0 MB 1.9 MB/s eta 0:00:03
#    --------------- ------------------------ 3.1/8.0 MB 1.8 MB/s eta 0:00:03
#    ---------------- ----------------------- 3.4/8.0 MB 1.7 MB/s eta 0:00:03
#    ------------------ --------------------- 3.7/8.0 MB 1.7 MB/s eta 0:00:03
#    ------------------- -------------------- 3.9/8.0 MB 1.6 MB/s eta 0:00:03
#    ------------------- -------------------- 3.9/8.0 MB 1.6 MB/s eta 0:00:03
#    -------------------- ------------------- 4.2/8.0 MB 1.5 MB/s eta 0:00:03
#    ---------------------- ----------------- 4.5/8.0 MB 1.5 MB/s eta 0:00:03
#    ------------------------ --------------- 5.0/8.0 MB 1.5 MB/s eta 0:00:03
#    -------------------------- ------------- 5.2/8.0 MB 1.5 MB/s eta 0:00:02
#    --------------------------- ------------ 5.5/8.0 MB 1.5 MB/s eta 0:00:02
#    ---------------------------- ----------- 5.8/8.0 MB 1.4 MB/s eta 0:00:02
#    ------------------------------ --------- 6.0/8.0 MB 1.4 MB/s eta 0:00:02
#    ------------------------------- -------- 6.3/8.0 MB 1.4 MB/s eta 0:00:02
#    ------------------------------- -------- 6.3/8.0 MB 1.4 MB/s eta 0:00:02
#    -------------------------------- ------- 6.6/8.0 MB 1.4 MB/s eta 0:00:02
#    -------------------------------- ------- 6.6/8.0 MB 1.4 MB/s eta 0:00:02
#    -------------------------------- ------- 6.6/8.0 MB 1.4 MB/s eta 0:00:02
#    --------------------------------- ------ 6.8/8.0 MB 1.2 MB/s eta 0:00:01
#    ----------------------------------- ---- 7.1/8.0 MB 1.2 MB/s eta 0:00:01
#    ------------------------------------ --- 7.3/8.0 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------  7.9/8.0 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------------- 8.0/8.0 MB 1.3 MB/s eta 0:00:00
# Downloading joblib-1.5.3-py3-none-any.whl (309 kB)
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, joblib, scikit-learn
# Successfully installed joblib-1.5.3 scikit-learn-1.8.0 threadpoolctl-3.6.0
# [notice] A new release of pip is available: 24.3.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = 0.1)

# %%
x_test
# Out:
#     cgpa     iq
# 22   4.9  120.0
# 84   5.7  169.0
# 69   8.5  120.0
# 93   6.8  112.0
# 44   7.5   61.0
# 17   3.3  183.0
# 47   5.2  161.0
# 70   6.3  127.0
# 7    5.0   63.0
# 65   8.1  166.0

# %% [markdown]
# ## scaling

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %% [raw]
# x_train = scaler.fit_transform(x_train)

# %%
x_train
# Out:
# array([[-9.93096869e-01, -1.56595818e+00],
#        [-5.31429936e-01,  4.02002153e-01],
#        [-7.16096709e-01, -8.34280618e-01],
#        [-9.00763482e-01, -1.27833321e-01],
#        [-1.82409735e+00, -5.81978012e-01],
#        [-6.23763322e-01, -2.28754363e-01],
#        [ 5.76570703e-01,  3.76771892e-01],
#        [-2.54429776e-01,  4.27232413e-01],
#        [-1.08543026e+00,  1.00752841e+00],
#        [ 2.99570543e-01, -5.06287230e-01],
#        [-9.93096869e-01,  7.04765280e-01],
#        [ 1.14903770e-01,  2.25390328e-01],
#        [-1.45476380e+00,  6.54304759e-01],
#        [ 1.03823764e+00,  7.04765280e-01],
#        [-5.31429936e-01, -2.28754363e-01],
#        [-8.08430095e-01,  1.24469286e-01],
#        [ 1.03823764e+00, -1.89395156e+00],
#        [ 9.45904249e-01, -1.49026739e+00],
#        [-1.08543026e+00,  1.15890997e+00],
#        [-8.08430095e-01,  1.33552180e+00],
#        [-8.08430095e-01, -1.43980687e+00],
#        [ 2.14623827e+00,  1.13367971e+00],
#        [ 3.91903930e-01,  4.52462674e-01],
#        [-1.54709719e+00,  1.94104805e+00],
#        [ 1.40757118e+00,  8.81377105e-01],
#        [ 6.68904089e-01,  7.80456062e-01],
#        [ 1.14903770e-01,  8.30916583e-01],
#        [-1.62096390e-01,  4.77692935e-01],
#        [ 9.45904249e-01, -2.79214884e-01],
#        [-1.27009703e+00,  5.78613977e-01],
#        [ 3.91903930e-01, -1.78293842e-01],
#        [ 8.53570862e-01,  4.02002153e-01],
#        [ 6.68904089e-01,  1.48690336e+00],
#        [ 1.22290441e+00,  3.51541631e-01],
#        [ 1.31523779e+00,  2.25390328e-01],
#        [ 4.84237316e-01, -2.17148443e+00],
#        [ 4.84237316e-01,  9.31837626e-01],
#        [-5.31429936e-01, -4.05366187e-01],
#        [-7.16096709e-01,  2.25390328e-01],
#        [ 1.22290441e+00, -1.78293842e-01],
#        [ 8.53570862e-01, -6.82899054e-01],
#        [-1.45476380e+00, -2.04533313e+00],
#        [-1.62096390e-01,  1.08321919e+00],
#        [ 2.25703834e-02,  6.54304759e-01],
#        [ 1.40757118e+00,  1.74929807e-01],
#        [ 7.61237476e-01, -8.34280618e-01],
#        [ 8.53570862e-01,  3.76771892e-01],
#        [ 9.45904249e-01,  1.31029154e+00],
#        [-2.54429776e-01,  5.02923195e-01],
#        [ 1.49990457e+00, -8.59510879e-01],
#        [ 1.14903770e-01, -1.06135296e+00],
#        [ 1.22290441e+00, -1.84349104e+00],
#        [ 1.68457134e+00, -2.28754363e-01],
#        [-6.23763322e-01, -5.21425386e-02],
#        [ 4.84237316e-01,  1.74929807e-01],
#        [-1.08543026e+00, -2.79214884e-01],
#        [ 1.86923811e+00, -1.11181349e+00],
#        [ 1.49990457e+00,  1.24469286e-01],
#        [ 7.61237476e-01, -1.68201738e-03],
#        [ 1.96157150e+00,  6.54304759e-01],
#        [-9.93096869e-01,  8.05686323e-01],
#        [-1.91643073e+00, -3.54905666e-01],
#        [-1.08543026e+00,  4.52462674e-01],
#        [ 1.14903770e-01, -5.06287230e-01],
#        [ 2.25703834e-02, -1.96964235e+00],
#        [-7.16096709e-01,  2.54657431e+00],
#        [ 2.25703834e-02, -5.31517491e-01],
#        [ 2.99570543e-01,  1.24469286e-01],
#        [-7.16096709e-01, -3.29675406e-01],
#        [ 2.25703834e-02, -1.43980687e+00],
#        [ 7.61237476e-01,  4.52462674e-01],
#        [-9.93096869e-01,  2.75850850e-01],
#        [ 4.84237316e-01, -8.34280618e-01],
#        [-2.54429776e-01,  2.25390328e-01],
#        [ 2.07237156e-01, -2.53984624e-01],
#        [ 9.45904249e-01,  1.91581779e+00],
#        [ 1.22290441e+00, -9.35201661e-01],
#        [ 5.76570703e-01, -7.73727993e-02],
#        [ 1.14903770e-01, -1.46503713e+00],
#        [-9.00763482e-01, -8.09050358e-01],
#        [-6.97630032e-02, -4.30596448e-01],
#        [-1.17776364e+00, -1.79303052e+00],
#        [-1.17776364e+00, -5.21425386e-02],
#        [-1.17776364e+00, -9.09971400e-01],
#        [ 2.25703834e-02,  2.35482433e-02],
#        [-9.93096869e-01,  1.84012701e+00],
#        [-5.31429936e-01,  3.01081110e-01],
#        [ 9.45904249e-01,  4.02002153e-01],
#        [-2.28576428e+00,  2.77364665e+00],
#        [-1.82409735e+00, -1.21273453e+00]])

# %%
x_test = scaler.transform(x_test)

# %%
x_test
# Out:
# array([[-0.99309687, -0.0773728 ],
#        [-0.25442978,  1.15890997],
#        [ 2.33090505, -0.0773728 ],
#        [ 0.76123748, -0.27921488],
#        [ 1.40757118, -1.56595818],
#        [-2.47043105,  1.51213362],
#        [-0.71609671,  0.95706789],
#        [ 0.29957054,  0.09923903],
#        [-0.90076348, -1.51549766],
#        [ 1.9615715 ,  1.08321919]])

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf = LogisticRegression()

# %%
# model training
clf.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
# model evaluation

# %%
y_pred = clf.predict(x_test)

# %% [markdown]
# y_test

# %% [markdown]
# # # our model correctly predicted the placements for the students

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 1.0

# %% [markdown]
# # now to visualize the boundary / rule that our model created

# %%
pip install mlxtend

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(x_train, y_train.values, clf=clf, legend=2)
